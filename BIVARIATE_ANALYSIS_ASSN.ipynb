# %% [markdown]
# ASSIGNMENT: ANALYSIS OF "PLACEMENT" DATASET

# %%
#IMPORT THE DATASET AS CSV FORMAT

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Question No.1: HOW TO REPLACE THE "nan" VALUE FROM THE DATASET ALSO EXPLAIN WHY WE NEED TO REPLACE IT?
#Salary coloumn == "Salary not given for 'No' placement candidate; therefore, we put '0' for 'NaN' value."

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# #Question No.2: HOW many of them are not placed?
# #In salary coloumn, from 67 candiadates not placed.

# %% [markdown]
# #Question No.3: Find the reason for non placement from the dataset?
# #In salary coloumn, Salary not given for 67 candiadates who are not placed.

# %%
def QuanQual(dataset):
    Quan=[]
    Qual=[]
    for ColumnName in dataset.columns:
        #print(columnName)
        if(dataset[ColumnName].dtype=='O'):
            #print("qual")
            Qual.append(ColumnName)
        else:
            #print("quan")
            Quan.append(ColumnName)
    return Quan,Qual

# %%
QuanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
Quan,Qual=QuanQual(dataset)

# %%
dataset[Quan].isnull().sum()
# Out:
# sl_no        0
# ssc_p        0
# hsc_p        0
# degree_p     0
# etest_p      0
# mba_p        0
# salary      67
# dtype: int64

# %% [markdown]
# #We got 67 null cell in the Salary Column

# %%
dataset["salary"].fillna(0,inplace=True)
# Out:
# C:\Users\ANIRUDH\AppData\Local\Temp\ipykernel_9460\2080798296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# #Checking the dataset have any "nan' values

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# #"Fillna" is used to replace the null value in the dataset. Here "Mean" is used to replace the null value.(Can use Median & Mode also)
# #dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)

# %% [markdown]
# Method: 2
# #The below dataset do not replace the "salary" column with mean - dataset not find the "nan" value instead "0.0"

# %%
#For all column we can find the nan value and replace the "mean value'

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[Quan])
datasetQuan=imp.transform(dataset[Quan])
#df = pd.DataFrame(df,columns = Quan)

# %%
imp
# Out:
# SimpleImputer()

# %%
datasetQuan
# Out:
# array([[1.000e+00, 6.700e+01, 9.100e+01, ..., 5.500e+01, 5.880e+01,
#         2.700e+05],
#        [2.000e+00, 7.933e+01, 7.833e+01, ..., 8.650e+01, 6.628e+01,
#         2.000e+05],
#        [3.000e+00, 6.500e+01, 6.800e+01, ..., 7.500e+01, 5.780e+01,
#         2.500e+05],
#        ...,
#        [2.130e+02, 6.700e+01, 6.700e+01, ..., 5.900e+01, 6.972e+01,
#         2.950e+05],
#        [2.140e+02, 7.400e+01, 6.600e+01, ..., 7.000e+01, 6.023e+01,
#         2.040e+05],
#        [2.150e+02, 6.200e+01, 5.800e+01, ..., 8.900e+01, 6.022e+01,
#         0.000e+00]])

# %%
datasetQuan = pd.DataFrame(datasetQuan,columns = Quan)

# %%
datasetQuan
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
dataset[Qual]
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
Qualdataset=dataset[Qual]
Quandataset=dataset[Quan]

# %%
frames = [datasetQuan, Qualdataset]
Finaldataset = pd.concat(frames,axis=1)
Finaldataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
Finaldataset.isna().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
Finaldataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    float64
#  1   ssc_p           215 non-null    float64
#  2   hsc_p           215 non-null    float64
#  3   degree_p        215 non-null    float64
#  4   etest_p         215 non-null    float64
#  5   mba_p           215 non-null    float64
#  6   salary          215 non-null    float64
#  7   gender          215 non-null    object
#  8   ssc_b           215 non-null    object
#  9   hsc_b           215 non-null    object
#  10  hsc_s           215 non-null    object
#  11  degree_t        215 non-null    object
#  12  workex          215 non-null    object
#  13  specialisation  215 non-null    object
#  14  status          215 non-null    object
# dtypes: float64(7), object(8)
# memory usage: 25.3+ KB

# %%
dataset.drop('sl_no',inplace=True,axis=1)
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
Finaldataset.to_csv('Placement_Pre-processed_Dataset.csv', header=True, index=False)

# %%
dataset1=pd.read_csv("Placement_Pre-processed_Dataset.csv")

# %%
dataset1
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
dataset1.drop('sl_no',inplace=True,axis=1)
dataset1
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset1.isnull().sum()
# Out:
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %% [markdown]
# #Question No.4: What kind of relation between Salary and Mba_Pass?

# %%
Quandataset.corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
datasetQuan = pd.DataFrame(Quandataset,columns = Quan)

# %%
x= datasetQuan['mba_p']  # Selecting 'mba_p' column
y = datasetQuan['salary']  # Selecting 'salary' column
correlation = y.corr(x)  # Calculating correlation between x and y
plt.title('Correlation between MBA and SALARY')
plt.scatter(x, y)  # Scatter plot
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), color='red')  # Adding regression line
plt.xlabel('mba_p')
plt.ylabel('salary')
plt.show()

# %%
print (correlation)
# Out:
# 0.13982273892615557

# %% [markdown]
# #Answer: There is no correlation (similarity) of "Mbp pass mark" and "Salary"
#
# #A correlation value of 0.13982273892615557 indicates a very weak positive correlation between the two variables.
# #This means that as one variable increases, the other variable tends to increase slightly,
# #but the relationship is not strong or particularly meaningful.
# #In practical terms, the variables are almost uncorrelated, and any relationship between them might not be significant.

# %%
#Question No.5: Which specialization is getting minimum salary(only placement)?

# %%
Ascending = dataset1["salary"].sort_values(ascending=True)
df_filtered = dataset1[Quandataset['salary'] !=0]
sorted_df_filtered = df_filtered.sort_values(by='salary')
min_salary = df_filtered['salary'].min()
df_min_salary = df_filtered[df_filtered['salary'] == min_salary]
print(df_min_salary.to_string(index=False))
# Out:
#  ssc_p  hsc_p  degree_p  etest_p  mba_p   salary gender   ssc_b   hsc_b    hsc_s  degree_t workex specialisation status
#  79.33  78.33     77.48     86.5  66.28 200000.0      M Central  Others  Science  Sci&Tech    Yes        Mkt&Fin Placed
#  65.00  75.00     69.00     72.0  64.66 200000.0      F Central Central Commerce Comm&Mgmt    Yes        Mkt&Fin Placed
#  77.00  73.00     81.00     89.0  69.70 200000.0      F  Others  Others Commerce Comm&Mgmt    Yes        Mkt&Fin Placed
#  75.20  73.20     68.40     65.0  62.98 200000.0      F Central Central  Science Comm&Mgmt     No         Mkt&HR Placed
#  82.00  90.00     83.00     80.0  73.52 200000.0      M  Others  Others Commerce Comm&Mgmt     No         Mkt&HR Placed
#  72.00  56.00     69.00     55.6  65.63 200000.0      F Central  Others  Science Comm&Mgmt     No         Mkt&HR Placed

# %% [markdown]
# #Answer: "Science & Tech" also "commerce and Management"

# %% [markdown]
# #Question No.6: How many of them getting above 500000 salary?

# %%
df = pd.DataFrame(dataset1)
rows_with_min_salary_500000 = df[df['salary'] >500000]
print(rows_with_min_salary_500000)
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 119   60.8  68.40      64.6    82.66  64.34  940000.0      M  Central
# 150   71.0  58.66      58.0    56.00  61.30  690000.0      M  Central
# 177   73.0  97.00      79.0    89.00  70.81  650000.0      F  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation  status
# 119  Central  Commerce  Comm&Mgmt    Yes        Mkt&Fin  Placed
# 150  Central   Science   Sci&Tech    Yes        Mkt&Fin  Placed
# 177   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin  Placed

# %%
len(rows_with_min_salary_500000)#to find total rows for how many person are getting the above salary of 500000
# Out:
# 3

# %% [markdown]
# #Answer: Around 3 members are getting below 500000 rupees.

# %% [markdown]
# #Question No.7: Test the Analysis of Variance between e_test and mba_p at significance level 5%.
# #(Make Decision making in Hypothesis Testing)
# #MALE

# %%
##Dependant Sample :Same Group(Male) but Different Condition(etest_p,mba_p)
from scipy.stats import ttest_rel
df=df.dropna()
male=df[df['gender']=="M"]['etest_p']
male1=df[df['gender']=="M"]['mba_p']
print ("Male:significance level (α)")
ttest_rel (male,male1)
# Out:
# Male:significance level (α)
# TtestResult(statistic=10.558377508518305, pvalue=1.8140319084982095e-19, df=138)

# %%
##Dependant Sample :Same Group(FeMale) but Different Condition(etest_p,mba_p)
from scipy.stats import ttest_rel
df=df.dropna()
Female=df[df['gender']=="F"]['etest_p']
Female1=df[df['gender']=="F"]['mba_p']
print ("FeMale:significance level (α)")
ttest_rel (Female,Female1)
# Out:
# FeMale:significance level (α)
# TtestResult(statistic=4.192176467486132, pvalue=7.476647595206423e-05, df=75)

# %% [markdown]
# #Answer: Set the significance level (α)=0.05
# There is no statistically significant difference between the sample mean and the population mean with MALE & Female to SALARY
# THE ABOVE CASE IS PVALUE of Male=1.81
# THE ABOVE CASE IS PVALUE of Female=7.47
#
# Note: ACCEPT H0 (NULL HYPOTHESIS) P VALUE > 0.05

# %% [markdown]
# #Question No.8:Test the similarity between the degree_t(Sci&Tech) at specialisation of(Mkt&HR)
# #with respect to salary at significance level of 5%(Make Decision making in Hypothesis Testing)

# %%
#Independant Sample: Diferrent Group(Sci&Tech, Mkt&HR) but same condition(salary)
from scipy.stats import ttest_ind
df=df.dropna()
Sci_Tech=df[df['degree_t']=="Sci&Tech"]['salary']
Mkt_HR=df[df['specialisation']=="Mkt&HR"]['salary']
ttest_ind (Sci_Tech,Mkt_HR)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %% [markdown]
# #Answer:
#  p-value <(0.0079) is less than the significance level (0.05),
#  we REJECT H0 (NULL HYPOTHESIS) P VALUE <0.05
#  We reject the null hypothesis (H₀) because the p-value is less than 0.05.
# This means there is statistically significant evidence to suggest that there is a difference between the sample mean and the population mean

# %%
df
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %% [markdown]
# #Question No.9: Convert the normal distribution to standard normal distribution for salary column?

# %%
#NORMAL DISTRIBUTION Type I
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df_filtered = df[df['salary'] != 0]
sns.distplot(df_filtered['salary'], kde=True)
plt.title('Distribution of Salary')
plt.xlabel('Salary')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\ANIRUDH\AppData\Local\Temp\ipykernel_9460\1148977476.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_filtered['salary'], kde=True)

# %%
#NORMAL DISTRIBUTION Type II
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df_filtered = df[df['salary'] != 0]
sns.kdeplot(df_filtered['salary'])
plt.title('Distribution of Salary')
plt.xlabel('Salary')
plt.ylabel('Probability Density Distribution')
plt.show()

# %% [markdown]
# #Answer: Visual impression of the distribution of data, showing the shape, spread, and central tendency.(HISTOGRAM)
# #Describe the overall pattern of data and to infer probabilities, expected values, variances, and other statistical properties.
# #Propabilities density Function by using Distribution

# %%
#STANDARD DISTRIBUTION
import seaborn as sns
df_filtered = df[df['salary'] != 0]
mean=df['salary'].mean()
std=df['salary'].std()
z_score=(df_filtered['salary']-mean)/std
sns.distplot(z_score,kde=True)
plt.title('Standardized Salary Distribution')
plt.xlabel('Standardized Salary')
plt.ylabel('Frequency')
plt.show()
print(f"MEAN: {mean} Standard Deviation: {std}")
# Out:
# C:\Users\ANIRUDH\AppData\Local\Temp\ipykernel_9460\396461165.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
# MEAN: 198702.32558139536 Standard Deviation: 154780.92671560097

# %% [markdown]
# #Answer: Standardized data converts values to z-scores, which indicate how many standard deviations a value is from the mean.
# #This makes it easier to understand the relative position of a value within the distribution.
# #Factors for changing the Normal Distribution to Standardized Distribution:
# # 1. Comparability
# (it allows features to contribute equally to the analysis.
# #Without standardization, features with larger scales could dominate the results)
# # 2. Statistical Analysis
# Accuracy and Outlier Detection
# # 3. Interpretability
# Standardized data converts values to z-scores

# %% [markdown]
# #Question No.10:What is the probability Density Function of the salary range from 700000 to 900000?

# %%
def get_pdf_probability(df,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(df,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = df
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(df["salary"],700000,900000)
# Out:
# C:\Users\ANIRUDH\AppData\Local\Temp\ipykernel_9460\790385635.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %% [markdown]
# Answer:
# The plot shows the salary distribution with vertical lines indicating the range of data with specific
# it helps to visualize the spread of the data.
# The area between range(700000,900000):0.0005973310593974868
# (its very less value)

# %% [markdown]
# #Question No.11:Test the similarity between the degree_t(Sci&Tech) with respect to e_test and mba_p at significance level of 5%
# #(Make Decision making in Hypothesis Testing)

# %%
##Dependant Sample :Same Group degree_t(Sci&Tech) but Different Condition(etest_p,mba_p)
from scipy.stats import ttest_rel
df=df.dropna()
Sci_Tech = df[df['degree_t']=="Sci&Tech"]['etest_p']
Sci_Tech1 = df[df['degree_t']=="Sci&Tech"]['mba_p']
print ("Science & Technical:significance level (α)")
ttest_rel (Sci_Tech,Sci_Tech1)
# Out:
# Science & Technical:significance level (α)
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %% [markdown]
# #Answer: Set the significance level (α)=0.05
# There is no significant result for both e_test and mba_p THE ABOVE CASE IS PVALUE=5.517..
# THEREFORE ACCEPT THE ABOVE H0 (NULL HYPOTHESIS)
# Note: ACCEPT H0 (NULL HYPOTHESIS) P VALUE > 0.05

# %%
#Question No.12:Which parameter is highly correlated with Salary?

# %%
Quandataset.drop('sl_no',inplace=True,axis=1)
Quandataset.corr()
# Out:
# C:\Users\ANIRUDH\AppData\Local\Temp\ipykernel_9460\3132690074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Quandataset.drop('sl_no',inplace=True,axis=1)
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
Quandataset.corrwith(Quandataset["salary"])
# Out:
# ssc_p       0.538090
# hsc_p       0.452569
# degree_p    0.408371
# etest_p     0.186988
# mba_p       0.139823
# salary      1.000000
# dtype: float64

# %% [markdown]
# Correlation with Salary: 0.5380 (Secondary School Percentage)
# •	Interpretation: The secondary school percentage ahs  positive correlation with salary
# It indicates that the variables move in the same direction. When one variable increases, the other also tends to increase.
#  This suggests that secondary school performance has little to no impact on salary in this datsaettCorrelation with Salary: 0.4525 (Higher Secondary School Percentage)
# •	Interpretation: The Higher secondary school percentage has positive correlation with salary
# It indicates that the variables move in the same direction. When one variable increases, the other also tends to increase.
#  This suggests that Higher secondary school performance has little to no impact on salary in this dataset
#
# Correlation with Salary: 0.4083 (Degree Percentage)
# •	Interpretation: The Degree percentage has positive correlation with salary
# It indicates that the variables move in the same direction. When one variable increases, the other also tends to increase.
#  This suggests that Degree Percentage performance has little to no impact on salary in this dataset
#
# Correlation with Salary: 0.1869 (Employability Test Percentage)
# •	Interpretation: The Employability Test percentage has very weak positive correlation with salary
# It indicates that the variables move in the same direction. When one variable increases, the other also tends to increase.
#  This suggests that Employability Test performance has little to no impact on salary in this dataset
#
# Correlation with Salary: 0.1398 (MBA Percentage)
# •	Interpretation: The MBA percentage has very weak positive correlation with salary
# It indicates that the variables move in the same direction. When one variable increases, the other also tends to increase.
#  This suggests that MBA percentage performance has little to no impact on salary in this dataset

# %%
#Question No.13:plot any useful graph and explain it?

# %%
import seaborn as sns
df_filtered = df[df['salary'] != 0]
sns.pairplot(df_filtered,hue="salary")
import matplotlib.pyplot as plt
plt.savefig('pairplot_Placement_Salary.png')
